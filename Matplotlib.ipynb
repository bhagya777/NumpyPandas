# %% [markdown]
# **84.Importing And Using Matplotlib**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[10,20,30,40,50,60,70]

# %%
plt.plot(x,y)

# %%
plt.show()
